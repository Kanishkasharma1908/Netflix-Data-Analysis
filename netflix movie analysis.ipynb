# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv("archive.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.duplicated()             # to check for duplicated columns or rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
df.describe()             # to check for only numerical values for statistics
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.isnull().sum()               # to check for null values
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # for code cell ---> markdown, ESC + M + enter
# # for markdown ---> code cell, ESC + Y + ENTER
# #EXPLORATION SUMMARY
# * We have a dataset of 8807 rows with 12 columns
# * The dataset contains no duplicate values but missing values in columns director, cast, country, date_added, rating, duration
# * Date added needs to be casted into date time and to extract only the year value
# * The description column is not needed for ananlysis so it will be dropped
# * Cast,date_added column has comma seperated values and white spaces which needs to be removed

# %% [markdown]
# # Data Cleaning

# %%
df['date_added'] = df['date_added'].str.strip()           # To strip the extra white spaces so that this doesnt give error
df['date_added'] = pd.to_datetime(df['date_added'])   
print(df['date_added'].dtype)                       # print(type(['date_added'])) ---> gives you the dtype of the whole column whiich is a pandas series
# Out:
# datetime64[ns]

# %%
df['date_added'] = df['date_added'].dt.year.astype('Int64')  # to extract only the year part of date 
print(df['date_added'].dtype)
# Out:
# Int64

# %%
# removing unwanted columns 
df.drop(['director','description'], axis = 1, inplace = True)    # inplace = to permanently remove cols, axis = 1 --> cols, 2 --> rows
df.head()
# Out:
#   show_id     type                  title  \
# 0      s1    Movie   Dick Johnson Is Dead
# 1      s2  TV Show          Blood & Water
# 2      s3  TV Show              Ganglands
# 3      s4  TV Show  Jailbirds New Orleans
# 4      s5  TV Show           Kota Factory
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    date_added  release_year rating   duration  \
# 0        2021          2020  PG-13     90 min
# 1        2021          2021  TV-MA  2 Seasons
# 2        2021          2021  TV-MA   1 Season
# 3        2021          2021  TV-MA   1 Season
# 4        2021          2021  TV-MA  2 Seasons
#
# ...

# %%
# Labelling the release year column into bins 

df['release_year'] = pd.to_numeric(df['release_year'])   
bins = [1900, 2000, 2010, 2020, 2030]
labels = ['Before 2000s', '2000s', '2010s', 'Recent']
df['release_year'] = pd.cut(df['release_year'], bins = bins, labels = labels)
df.head()
# Out:
#   show_id     type                  title  \
# 0      s1    Movie   Dick Johnson Is Dead
# 1      s2  TV Show          Blood & Water
# 2      s3  TV Show              Ganglands
# 3      s4  TV Show  Jailbirds New Orleans
# 4      s5  TV Show           Kota Factory
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    date_added release_year rating   duration  \
# 0        2021        2010s  PG-13     90 min
# 1        2021       Recent  TV-MA  2 Seasons
# 2        2021       Recent  TV-MA   1 Season
# 3        2021       Recent  TV-MA   1 Season
# 4        2021       Recent  TV-MA  2 Seasons
#
# ...

# %%
df['release_year'].unique()
# Out:
# ['2010s', 'Recent', 'Before 2000s', '2000s']
# Categories (4, object): ['Before 2000s' < '2000s' < '2010s' < 'Recent']

# %%
df['release_year'].value_counts()
# Out:
# release_year
# 2010s           6686
# 2000s            967
# Recent           592
# Before 2000s     562
# Name: count, dtype: int64

# %%
#to remove NA values from all columns 
df.dropna(inplace =  True)
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df.head()
# Out:
#   show_id     type                          title  \
# 1      s2  TV Show                  Blood & Water
# 4      s5  TV Show                   Kota Factory
# 7      s8    Movie                        Sankofa
# 8      s9  TV Show  The Great British Baking Show
# 9     s10    Movie                   The Starling
#
#                                                 cast  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country  date_added  \
# 1                                       South Africa        2021
# 4                                              India        2021
# 7  United States, Ghana, Burkina Faso, United Kin...        2021
# 8                                     United Kingdom        2021
# ...

# %%
# EXploding the listed_in column such that each genre comes in each line 
df['listed_in'] = df['listed_in'].str.split(', ')          
df = df.explode('listed_in').reset_index(drop = True)

# %%
# Converting into category data type
df['listed_in'] = df['listed_in'].astype('category')
df.head()
# Out:
#   show_id     type          title  \
# 0      s2  TV Show  Blood & Water
# 1      s2  TV Show  Blood & Water
# 2      s2  TV Show  Blood & Water
# 3      s5  TV Show   Kota Factory
# 4      s5  TV Show   Kota Factory
#
#                                                 cast       country  \
# 0  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 3  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
#
#    date_added release_year rating   duration               listed_in
# 0        2021       Recent  TV-MA  2 Seasons  International TV Shows
# 1        2021       Recent  TV-MA  2 Seasons               TV Dramas
# 2        2021       Recent  TV-MA  2 Seasons            TV Mysteries
# 3        2021       Recent  TV-MA  2 Seasons  International TV Shows
# ...

# %% [markdown]
# # Data VIsualization

# %% [markdown]
# # Most frequent genre of movies released

# %%
sn.catplot(y = 'listed_in', data = df, order = df['listed_in'].value_counts().index, color = 'blue', kind = 'count',   # to get the value counts of each genre in listed_in column
    height=15,      # taller           # index --> to arrange the order based on index (whoever comes first)
    aspect= 0.5   )  # wider
plt.title('genre frequency graph')
plt.show()   #Seaborn automatically chooses tick intervals (0, 1000, 2000, etc.) based on the largest count

# %% [markdown]
# # frequency of movies released in each year

# %%
 # Category plotting 
sn.catplot( y = 'release_year', data = df, order = df['release_year'].value_counts().index, kind = 'count')
plt.title('frequency of movies released in each year')
plt.show()

# %% [markdown]
# # which country has the most movies

# %%
max_movies = df['country'].value_counts().idxmax()
max_movies
# Out:
# 'United States'

# %%
# Country with minimum movies
min_movie = df['country'].value_counts().idxmin()  # country with minimum number of movies
min_movie
# Out:
# 'United Kingdom, Hong Kong'

# %% [markdown]
# # Frequency of movies added in netflix  per year

# %%
df['date_added'].hist()
plt.show()

# %%
df.head()
# Out:
#   show_id     type          title  \
# 0      s2  TV Show  Blood & Water
# 1      s2  TV Show  Blood & Water
# 2      s2  TV Show  Blood & Water
# 3      s5  TV Show   Kota Factory
# 4      s5  TV Show   Kota Factory
#
#                                                 cast       country  \
# 0  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 3  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
#
#    date_added release_year rating   duration               listed_in
# 0        2021       Recent  TV-MA  2 Seasons  International TV Shows
# 1        2021       Recent  TV-MA  2 Seasons               TV Dramas
# 2        2021       Recent  TV-MA  2 Seasons            TV Mysteries
# 3        2021       Recent  TV-MA  2 Seasons  International TV Shows
# ...
